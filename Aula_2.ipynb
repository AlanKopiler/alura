# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanKopiler/alura/blob/main/Aula_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

fonte = "https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true"

dados = pd.read_csv(fonte)

# %% [markdown]
# ## **Desafio 1**

# %%
dados.query("NU_IDADE==13 or NU_IDADE==14")
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 310     190001016485    2019                  1501402  ...    A     A    A
# 2818    190001116721    2019                  2202406  ...    A     A    A
# 3022    190001124999    2019                  2100303  ...    A     B    B
# 5748    190001229936    2019                  2908408  ...    A     A    A
# 8845    190001353348    2019                  2600104  ...    A     B    B
# ...              ...     ...                      ...  ...  ...   ...  ...
# 123574  190005947160    2019                  5004502  ...    A     E    B
# 124683  190005993245    2019                  3538808  ...    A     B    B
# 125999  190006045655    2019                  5300108  ...    B     B    B
# 127008  190006099362    2019                  3109105  ...    A     A    B
# 127318  190006117130    2019                  2507507  ...    A     A    B
#
# [145 rows x 136 columns]

# %% [markdown]
# ## **Desafio 2**

# %%
total = len(dados.query("NU_IDADE<18"))
dados.query("NU_IDADE<18").SG_UF_RESIDENCIA.value_counts()/total*100
# Out:
# SP    23.434699
# MG    10.070423
# BA     6.379641
# CE     6.251601
# PE     5.777849
# PR     5.646607
# RJ     5.284891
# PA     4.058899
# GO     3.838028
# MA     3.725992
# RS     3.169014
# PB     2.682458
# SC     2.544814
# PI     2.170294
# MT     1.959027
# ES     1.654930
# DF     1.510883
# AL     1.427657
# RN     1.373239
# AM     1.370038
# MS     1.347631
# SE     1.296415
# TO     1.101152
# RO     0.749040
# AP     0.601793
# AC     0.348912
# RR     0.224072
# Name: SG_UF_RESIDENCIA, dtype: float64

# %% [markdown]
# # **Desafio 3**

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.boxplot(x="SG_UF_RESIDENCIA", y = "NU_NOTA_REDACAO", data = dados)
plt.title("Boxplot das notas de redação pelo estado")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de redação pelo estado')

# %% [markdown]
# ## **Desafio 4 e 5**

# %%
dados.query('TP_PRESENCA_CN==0' and 'TP_PRESENCA_CH==0' and 'TP_PRESENCA_LC==0' and'TP_PRESENCA_MT==0' and 'TP_STATUS_REDACAO=="NaN"')
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 10      190001005028    2019                  1506807  ...    A     A    A
# 11      190001005057    2019                  1501709  ...    A     A    B
# 26      190001005484    2019                  1504208  ...    A     B    B
# 38      190001006086    2019                  1508126  ...    A     A    B
# 40      190001006292    2019                  1504422  ...    A     A    B
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127351  190006118552    2019                  2604106  ...    A     B    B
# 127365  190006119756    2019                  2302503  ...    A     A    A
# 127366  190006119783    2019                  2304400  ...    B     B    A
# 127368  190006119802    2019                  2507507  ...    A     A    B
# 127374  190006119995    2019                  2927408  ...    A     B    B
#
# [29337 rows x 136 columns]

# %%
dados.query('NU_NOTA_CN==0' and 'NU_NOTA_CH==0' and 'NU_NOTA_LC==0' and 'NU_NOTA_MT==0' and 'NU_NOTA_REDACAO==0')
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 20      190001005274    2019                  1504208  ...    A     A    B
# 22      190001005335    2019                  1501402  ...    A     A    B
# 29      190001005649    2019                  1507300  ...    A     C    B
# 65      190001007253    2019                  1502202  ...    A     A    A
# 147     190001009842    2019                  1500107  ...    A     B    A
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127106  190006104734    2019                  2611903  ...    A     A    A
# 127159  190006108067    2019                  3170206  ...    B     A    B
# 127240  190006112478    2019                  2210631  ...    A     A    B
# 127268  190006114139    2019                  2408102  ...    A     A    A
# 127370  190006119820    2019                  2513901  ...    A     A    A
#
# [3505 rows x 136 columns]

# %% [markdown]
# ## **Desafio 6**

# %%
total = len(dados.NU_INSCRICAO.value_counts())
dados.query("IN_TREINEIRO==0")["Q006"].value_counts().sort_index()/total*100
# Out:
# A     4.116816
# B    22.580468
# C    23.572774
# D     8.915057
# E     8.318417
# F     3.756477
# G     5.079290
# H     3.023238
# I     2.228764
# J     1.278066
# K     0.894960
# L     0.625687
# M     0.612341
# N     0.861203
# O     0.736379
# P     0.590360
# Q     0.719108
# Name: Q006, dtype: float64

# %%
total = len(dados.NU_INSCRICAO.value_counts())
dados.query("IN_TREINEIRO==1")["Q006"].value_counts().sort_index()/total*100
# Out:
# A    0.467891
# B    2.376354
# C    2.015230
# D    0.941278
# E    0.994662
# F    0.671220
# G    0.829801
# H    0.757576
# I    0.559743
# J    0.369760
# K    0.268488
# L    0.241011
# M    0.243366
# N    0.342283
# O    0.305385
# P    0.298320
# Q    0.408227
# Name: Q006, dtype: float64

# %% [markdown]
# ## **Desafio** **7**

# %%
legenda = ['Tem','Não tem']
dados["Q025"].value_counts().plot.pie(figsize=(5,5), autopct = '%1.1f%%',)
plt.legend(legenda, ncol=1, loc='center right', bbox_to_anchor=(0.8,0.2,0.5,0.5))
plt.title('Proporção de quem tem internet em casa')
# Out:
# Text(0.5, 1.0, 'Proporção de quem tem internet em casa')
